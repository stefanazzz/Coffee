# %% [markdown]
# ## Specific libraries for image proc (PIL, cv2)<br> and OCR (pytesseract):

# %%
from PIL import Image
import pytesseract
import cv2

# %% [markdown]
# ## Import bitmap image<br>Save to temporary file<br>(and optional preview of bitmap):

# %%
image = cv2.imread("example.png") #read using cv2 module
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # convert to gray numbers using cv2
filename = "{}.png".format("temp") # create temp file 
cv2.imwrite(filename, gray) # save as temp file
# Out:
# True

# %%
# optional preview of image:
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
plt.imshow(image);
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# ## Interpret as text using tesseract module:

# %%
text = pytesseract.image_to_string(Image.open(filename))
print(text)
# Out:
# Equipment list for the Department of Earth Sciences
# Fieldwork (Geophysical) ~ GEOL2241
# Easter Vacation Fieldtrip
#
# Gravimeters
# 2x Gravimeter (1. departmental, 1 BGS loan; inclu
# 2x Gravimeter and battery chargers
#
# Any spare gravimeter batteries
#
#
#
# 1g 2 batteries each)
#
# Magnetometers
# 4.x magnetometers (1 x base station, 3 x roving magnetometers; including batteries and
#
# charging units)
#
# GPS/levelling
# 5 x EMLID REACH GPS units (including any associated poles/tripod)
#
# © 1 base station unit
#
# © 4 ,oving units (one for each group + spare}
# 4x Handheld GPS units.
# Levelling staff
# Levelling tripod and sights
#
# Resistivity
# Tigre 2D-resistivity kit, including laptop, all cables, extensions, and electrode pins.
#
# 2.x Wenner array control boxes
#
# 2.x Wenner array cable reels
#
# 4x Wenner electrodes
#
# Wenner control box chargers
#
# Offset Wenner resistivity kit and associated electrades and batteries/chargers
#
# Electromagnetic
# ...
