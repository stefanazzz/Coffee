# %%
from scipy import integrate
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
a=[1 ,2 , 5,0,0,0,5,2,6]
t=[.1,.2,.3,.4,.5,.6,.7,.8,.9]
aint=integrate.cumtrapz(a,t,initial=0)

# %%
aint
# Out:
# array([0.  , 0.15, 0.5 , 0.75, 0.75, 0.75, 1.  , 1.35, 1.75])

# %%
plt.plot(t,a)

# %%
plt.plot(t,aint)
